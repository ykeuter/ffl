# %%
from ffl import espn, shark, models
import pandas as pd
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
league_ids = [
    19470, # Road to Glory
    1317521, # Los Chivos
]

scorings = [
    10, # ESPN
    2, # PPR
]

segments = [
    #638, # Week 11
    639, # Week 12
    #640, # Week 13
    #641, # Week 14
    #642, # Week 15
    #643, # Week 16
    #621, # Rest of 2018 season
]

# %%
for i in league_ids:
    espn.update_projections(i)
# Out:
# /Users/ykeuter/ffl/.venv/lib/python3.5/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# Updated ESPN projections for league 19470.
# Updated ESPN projections for league 1317521.

# %%
for sc in scorings:
    for se in segments:
        shark.update_projections(se, sc)
# Out:
# Updated Fantasy Shark projections for segment 639 and scoring 10.
# Missing ESPN player for Robert Martin (13896).
# Updated Fantasy Shark projections for segment 639 and scoring 2.
# Missing ESPN player for Robert Martin (13896).

# %%
league_id = 19470 # 1317521 19470
scoring = 10
segment = 639
position = "D"
players = models.SharkProjections.query.filter_by(position=position, segment=segment, scoring=scoring).all()
df = pd.DataFrame(columns=["name", "status", "pts"])
for p in players:
    status = next((e.status for e in p.player.espn_projections if e.league_id == league_id), None)
    df = df.append({"name": p.player_name, "status": status, "pts": p.points}, ignore_index=True)
pd.options.display.max_rows = None
display(df.sort_values("pts", ascending=False))
# Out:
#                     name    status    pts
# 0   Los Angeles Chargers      NELI  13.60
# 1          Chicago Bears      LUYD  10.60
# 2    Pittsburgh Steelers  WA (Wed)  10.50
# 3          Buffalo Bills  WA (Wed)   8.60
# 4   New England Patriots      KEUT   8.30
# 5   Jacksonville Jaguars      BURG   7.90
# 6       Baltimore Ravens      BRUN   7.80
# 7      Minnesota Vikings      NELI   7.40
# 8         Houston Texans        EL   7.20
# 9    San Francisco 49ers      BURG   6.90
# 10      Tennessee Titans  WA (Wed)   5.40
# 11     Green Bay Packers      BRUN   5.20
# 12    Indianapolis Colts       GBP   5.10
# 13    Cincinnati Bengals  WA (Wed)   5.00
# 15   Washington Redskins       GBP   4.70
# 14    New Orleans Saints      Ray    4.70
# 16      Seattle Seahawks  WA (Wed)   4.20
# 17      Cleveland Browns  WA (Wed)   3.90
# 18  Tampa Bay Buccaneers  WA (Wed)   3.80
# 19     Carolina Panthers      BRUN   3.60
# 20   Philadelphia Eagles      HUSK   3.30
# 21        Dallas Cowboys  WA (Wed)   3.10
# 22        Denver Broncos  WA (Wed)   2.40
# 23       New York Giants  WA (Wed)   2.20
# 24     Arizona Cardinals  WA (Wed)   2.00
# 25        Miami Dolphins  WA (Wed)  -0.56
# 26         Detroit Lions  WA (Wed)  -0.68
# 27       Oakland Raiders  WA (Wed)  -0.69
# 28         New York Jets  WA (Thu)  -4.31
# 29       Atlanta Falcons  WA (Wed)  -7.34
